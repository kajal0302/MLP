# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.iloc[3]
# Out:
# #                                 3
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# Type 2                       Poison
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object

# %%
df.iloc[3][2]
# Out:
# 'Grass'

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['HP','Name','Attack']]
# Out:
#      HP                   Name  Attack
# 0    45              Bulbasaur      49
# 1    60                Ivysaur      62
# 2    80               Venusaur      82
# 3    80  VenusaurMega Venusaur     100
# 4    39             Charmander      52
# ..   ..                    ...     ...
# 795  50                Diancie     100
# 796  50    DiancieMega Diancie     160
# 797  80    HoopaHoopa Confined     110
# 798  80     HoopaHoopa Unbound     160
# 799  80              Volcanion     110
#
# [800 rows x 3 columns]

# %%
df[(df['HP']>60)]
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 2      3                   Venusaur    Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur    Grass  Poison   80     100      123
# 6      6                  Charizard     Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying   78     104       78
# ..   ...                        ...      ...     ...  ...     ...      ...
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme   Dragon  Ground  108     100      121
# 797  720        HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799  721                  Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['HP']<50) & (df['Attack']<80)]
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 4      4             Charmander    Fire     NaN  39      52       43       60
# 9      7               Squirtle   Water     NaN  44      48       65       50
# 13    10               Caterpie     Bug     NaN  45      30       35       20
# 16    13                 Weedle     Bug  Poison  40      35       30       20
# ..   ...                    ...     ...     ...  ..     ...      ...      ...
# 774  704                  Goomy  Dragon     NaN  45      50       35       55
# 778  708               Phantump   Ghost   Grass  43      70       48       50
# 780  710  PumpkabooAverage Size   Ghost   Grass  49      66       70       44
# 781  710    PumpkabooSmall Size   Ghost   Grass  44      66       70       44
# 790  714                 Noibat  Flying  Dragon  40      30       35       45
#
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Generation']+df['Defense']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    144
# ...

# %%
df.sort_values(['HP','Attack'], ascending=[1,1])
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 230  213    Shuckle      Bug   Rock   20      10      230       10      230
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary  Total
# ...

# %%
df.drop_duplicates()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    144
# ...

# %%
df.drop(columns=['Total','Attack'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45       49       65
# 1      2                Ivysaur    Grass  Poison  60       63       80
# 2      3               Venusaur    Grass  Poison  80       83      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80      123      122
# 4      4             Charmander     Fire     NaN  39       43       60
# ..   ...                    ...      ...     ...  ..      ...      ...
# 795  719                Diancie     Rock   Fairy  50      150      100
# 796  719    DiancieMega Diancie     Rock   Fairy  50      110      160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80       60      150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80       60      170
# 799  721              Volcanion     Fire   Water  80      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation       Total
# count  800.000000   800.00000  800.000000
# mean    68.277500     3.32375  225.426250
# std     29.060474     1.66129   68.303395
# min      5.000000     1.00000   58.000000
# 25%     45.000000     2.00000  173.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
#  12  Total       800 non-null    int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name'].count()
# Out:
# 800

# %%
df['HP'].min()
# Out:
# 1

# %%
df['HP'].max()
# Out:
# 255

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# Total           0
# dtype: int64

# %%
type2=df['Type 2']
type2
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object
